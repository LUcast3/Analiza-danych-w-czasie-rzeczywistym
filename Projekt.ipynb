# %%
import pandas as pd
import glob, os

# 1. Wylistuj pliki
files = glob.glob("*.csv")
print("Znalezione pliki:", files)

# 2. Wczytaj pierwszy plik bez parse_dates i obejrzyj nazwy kolumn
sample = pd.read_csv(files[0], nrows=5)
print("\nKolumny w pliku", files[0], ":\n", sample.columns.tolist())
sample.head()
# Out:
# Znalezione pliki: ['alerts_log.csv', 'alerty.csv', 'HDFCBANK_minute.csv', 'ICICIBANK_minute.csv', 'INFY_minute.csv', 'RELIANCE_minute.csv', 'TCS_minute.csv']
#
# Kolumny w pliku alerts_log.csv :
#  ['timestamp', 'symbol', 'close', 'volume', 'zscore', 'alert_type', 'logged_at']
#              timestamp     symbol    close   volume  zscore    alert_type  \
# 0  2015-02-02T10:20:00       INFY   534.50   813820    5.38  [⚠️ WARNING]
# 1  2015-02-02T11:40:00   RELIANCE   215.50   731120    5.38  [⚠️ WARNING]
# 2  2015-02-02T11:46:00       INFY   536.98   408712    5.38  [⚠️ WARNING]
# 3  2015-02-02T12:22:00  ICICIBANK   319.00  1160519    5.36  [⚠️ WARNING]
# 4  2015-02-02T13:12:00        TCS  1249.43   202476    5.38  [⚠️ WARNING]
#
#                     logged_at
# 0  2025-06-05T20:23:45.109701
# 1  2025-06-05T20:23:45.474486
# 2  2025-06-05T20:23:45.499082
# 3  2025-06-05T20:23:45.653754
# 4  2025-06-05T20:23:45.842691

# %%
files = glob.glob("*_minute.csv")
print("Znalezione pliki:", files)

dfs = []
for fn in files:
    ticker = os.path.basename(fn).split("_minute")[0]
    
    # Wczytanie i parsowanie kolumny 'date'
    df_tmp = pd.read_csv(fn, parse_dates=["date"])
    
    # Zmiana nazwy
    df_tmp.rename(columns={"date": "DateTime"}, inplace=True)
    
    # Dodanie kolumny z tickerem
    df_tmp["Symbol"] = ticker
    
    dfs.append(df_tmp)

# 3. Scal wszystko w jeden DataFrame
df = pd.concat(dfs, ignore_index=True)

# 4. Sortowanie i reset indeksu
df.sort_values(["Symbol", "DateTime"], inplace=True)
df.reset_index(drop=True, inplace=True)

# 5. Podsumowanie
print(f"Wczytano {len(files)} plików, łącznie {df.shape[0]} wierszy")
print(df.groupby("Symbol")["DateTime"].agg(["min", "max", "count"]))
df.head()
# Out:
# Znalezione pliki: ['HDFCBANK_minute.csv', 'ICICIBANK_minute.csv', 'INFY_minute.csv', 'RELIANCE_minute.csv', 'TCS_minute.csv']
# Wczytano 5 plików, łącznie 4517554 wierszy
#                           min                 max   count
# Symbol
# HDFCBANK  2015-02-02 09:15:00 2024-11-08 15:29:00  903519
# ICICIBANK 2015-02-02 09:15:00 2024-11-08 15:29:00  903521
# INFY      2015-02-02 09:15:00 2024-11-08 15:29:00  903522
# RELIANCE  2015-02-02 09:15:00 2024-11-08 15:29:00  903474
# TCS       2015-02-02 09:15:00 2024-11-08 15:29:00  903518
#              DateTime    open    high     low   close  volume    Symbol
# 0 2015-02-02 09:15:00  532.90  532.90  530.20  530.90   12719  HDFCBANK
# 1 2015-02-02 09:16:00  531.55  531.90  530.75  530.75    9437  HDFCBANK
# 2 2015-02-02 09:17:00  530.75  531.70  530.75  531.45    3500  HDFCBANK
# 3 2015-02-02 09:18:00  531.45  531.45  530.40  530.50    5203  HDFCBANK
# 4 2015-02-02 09:19:00  530.50  530.75  529.80  529.80    3386  HDFCBANK

# %%
# Sortowanie
df.sort_values(["Symbol","DateTime"], inplace=True)
df.reset_index(drop=True, inplace=True)

# 2. Procentowa zmiana ceny (close względem poprzedniego ticka)
df["pct_change"] = df.groupby("Symbol")["close"].pct_change() * 100
# Zastępujemy inf/-inf na NaN, potem można w razie potrzeby wyczyścić lub uzupełnić
df["pct_change"] = df["pct_change"].replace([float("inf"), float("-inf")], pd.NA)

df.dropna(subset=["pct_change"], inplace=True)

# 3. Z-score wolumenu w oknie 30-minutowym
grouped = df.groupby("Symbol")["volume"]
df["vol_mean_30"]  = grouped.rolling(window=30, min_periods=5).mean().reset_index(0,drop=True)
df["vol_std_30"]   = grouped.rolling(window=30, min_periods=5).std().reset_index(0,drop=True)
df["vol_zscore"]   = (df["volume"] - df["vol_mean_30"]) / df["vol_std_30"]

# %%
df.head()
# Out:
#              timestamp     symbol    close   volume  zscore    alert_type  \
# 0  2015-02-02T10:20:00       INFY   534.50   813820    5.38  [⚠️ WARNING]
# 1  2015-02-02T11:40:00   RELIANCE   215.50   731120    5.38  [⚠️ WARNING]
# 2  2015-02-02T11:46:00       INFY   536.98   408712    5.38  [⚠️ WARNING]
# 3  2015-02-02T12:22:00  ICICIBANK   319.00  1160519    5.36  [⚠️ WARNING]
# 4  2015-02-02T13:12:00        TCS  1249.43   202476    5.38  [⚠️ WARNING]
#
#                     logged_at
# 0  2025-06-04T19:34:02.422790
# 1  2025-06-04T19:34:02.693533
# 2  2025-06-04T19:34:02.712969
# 3  2025-06-04T19:34:02.834758
# 4  2025-06-04T19:34:02.998609

# %%
# Parametry alertów
BUY_PCT     = 2.5
SELL_PCT    = -2.5
VOL_BUY     = 2.0
VOL_SELL    = 2.0
WARN_VOL    = 5.0
WARN_PCT    = 1.2

def detect_anomalies(df):
    alerts = []

    for _, row in df.iterrows():
        pct_change = row.get("pct_change", 0)
        vol_zscore = row.get("vol_zscore", 0)
        timestamp = row.get("DateTime")
        symbol = row.get("Symbol")
        close = row.get("close")
        volume = row.get("volume")

        alert_type = None

        if pct_change > BUY_PCT and vol_zscore >= VOL_BUY:
            alert_type = "[🚀 BUY]"
        elif pct_change < SELL_PCT and vol_zscore >= VOL_SELL:
            alert_type = "[🔻 SELL]"
        elif abs(vol_zscore) >= WARN_VOL:
            alert_type = "[⚠️ WARNING]"
        elif abs(pct_change) >= WARN_PCT and abs(vol_zscore) < VOL_BUY:
            alert_type = "[⚠️ WARNING]"

        if alert_type:
            alerts.append({
                "timestamp": timestamp,
                "symbol": symbol,
                "close": close,
                "volume": volume,
                "zscore": round(vol_zscore, 2),
                "alert_type": alert_type
            })

    alert_df = pd.DataFrame(alerts)
    return alert_df

# %%
alert_df = detect_anomalies(df)

# %%
alert_df['alert_type'].value_counts()
# Out:
# alert_type
# [⚠️ WARNING]    9669
# [🔻 SELL]         322
# [🚀 BUY]          277
# Name: count, dtype: int64

# %%
# alert_df.to_csv("alerty.csv", index=False)

# %%
print(df.columns)
# Out:
# Index(['timestamp', 'symbol', 'close', 'volume', 'zscore', 'alert_type',
#        'logged_at'],
#       dtype='object')

# %%
from kafka import KafkaConsumer
from collections import deque, defaultdict
import numpy as np
from datetime import datetime

# Parametry alertów
BUY_PCT     = 2.5 # pct_change > 2,5% → kupuj
SELL_PCT    = -2.5 # pct_change < -2,5% → sprzedaj
VOL_BUY     = 2.0 # vol_zscore ≥ 2 → wolumen potwierdza ruch
VOL_SELL    = 2.0 # analogicznie dla sprzedaży
WARN_VOL    = 5.0 # wolumen bardzo wysoki → ostrzeżenie
WARN_PCT    = 1.2 # umiarkowany ruch cenowy → ostrzeżenie

# Konfiguracja konsumenta
consumer = KafkaConsumer(
    'prices',
    bootstrap_servers='localhost:9092',
    auto_offset_reset='latest',
    enable_auto_commit=True,
    value_deserializer=lambda m: json.loads(m.decode('utf-8'))
)

# Funkcja logująca alert
def log_alert(alert_type, tick, score):
    row = {
        "timestamp": tick["timestamp"],
        "symbol": tick["Symbol"],
        "close": tick["close"],
        "volume": tick["volume"],
        "zscore": round(score, 2),
        "alert_type": alert_type,
        "logged_at": datetime.utcnow().isoformat()
    }
    df = pd.DataFrame([row])
    df.to_csv("alerts_log.csv", mode='a', header=False, index=False)
    
# Bufory
buffers = defaultdict(lambda: deque(maxlen=30))

print("🛰️ Nasłuchiwanie ticków i wykrywanie anomalii...")

df = pd.read_csv("alerts_log.csv")
df.iloc[0:0].to_csv("alerts_log.csv", index=False)

for message in consumer:
    tick = message.value
    timestamp = tick["timestamp"]
    symbol = tick["Symbol"]
    close = tick["close"]
    volume = tick["volume"]
    
    buffers[symbol].append({"close": close, "volume": volume})


    # Liczenie cech przy wystarczającej liczbie danych
    if len(buffers[symbol]) >= 5:
        data = list(buffers[symbol])
        closes = [x["close"] for x in data]
        volumes = [x["volume"] for x in data]

        # pct_change – zmiana % ceny
        pct_change = ((closes[-1] - closes[-2]) / closes[-2]) * 100 if closes[-2] != 0 else 0

        # vol_zscore – z-score wolumenu
        vol_mean = np.mean(volumes)
        vol_std = np.std(volumes)
        vol_zscore = (volume - vol_mean) / vol_std if vol_std != 0 else 0

        # flagi
        flag_no_volume = int(volume == 0)
        flag_ohlc_error = int(
            tick["close"] < tick["low"] or tick["close"] > tick["high"] or
            tick["open"] < tick["low"] or tick["open"] > tick["high"]
        )

        # Reguły anomalii
        # if vol_zscore > 7 and abs(pct_change) < 0.1:
        #     alert_type = "[📊 WATCH]"
        #     print(f" {alert_type} {timestamp} | {symbol} | Ekstremalny wolumen bez zmiany ceny ({vol_zscore:.2f}σ) → Obserwuj")
        #     log_alert(alert_type, tick, round(vol_zscore, 2))
        
                # elif flag_no_volume:
        #     alert_type = "[⏸ HOLD]"
        #     print(f"{alert_type} {timestamp} | {symbol} | Brak wolumenu w godzinach handlu → Wstrzymaj się z transakcjami")
        #     log_alert(alert_type, tick, round(vol_zscore, 2))

#         elif flag_ohlc_error:
#             alert_type = "[⚠️ HOLD]"
#             print(f"{alert_type} {timestamp} | {symbol} | Błąd OHLC → Zweryfikuj dane, nie podejmuj decyzji")
#             log_alert(alert_type, tick, round(vol_zscore, 2))

#         elif abs(pct_change) > 3.0 and abs(vol_zscore) < 1.5:
#             alert_type = "[⌛ REVIEW]"
#             print(f"{alert_type} {timestamp} | {symbol} | Duży ruch ceny ({pct_change:.2f}%), wolumen ok ({vol_zscore:.2f}σ) → Poczekaj na potwierdzenie")
#             log_alert(alert_type, tick, round(vol_zscore, 2))

        if pct_change > BUY_PCT and vol_zscore >= VOL_BUY:
            alert_type = "[🚀 BUY]"
            print(f"{alert_type} {timestamp} | {symbol} | Wzrost {pct_change:.2f}% + wolumen {vol_zscore:.2f}σ → Sygnał do kupna")
            log_alert(alert_type, tick, round(vol_zscore, 2))

        elif pct_change < SELL_PCT and vol_zscore >= VOL_SELL:
            alert_type = "[🔻 SELL]"
            print(f"{alert_type} {timestamp} | {symbol} | Spadek {pct_change:.2f}% + wolumen {vol_zscore:.2f}σ → Sygnał do sprzedaży")
            log_alert(alert_type, tick, round(vol_zscore, 2))

        elif abs(vol_zscore) >= WARN_VOL:
            alert_type = "[⚠️ WARNING]"
            print(f"{alert_type} {timestamp} | {symbol} | Wolumen: {vol_zscore: .2f}σ → Bądź czujny - Bardzo duży wolumen ")
            log_alert(alert_type, tick, round(vol_zscore, 2))
            
        elif abs(pct_change) >= WARN_PCT and abs(vol_zscore) < VOL_BUY:
            alert_type = "[⚠️ WARNING]"
            print(f"{alert_type} {timestamp} | {symbol} | Ruch ceny: {pct_change: .2f}% (ₓ), wolumen: {vol_zscore: .2f}σ (niski) → Uwaga - możliwa manipulacja, wzrosty bez wolumenu")
            log_alert(alert_type, tick, round(vol_zscore, 2))
# Out:
# 🛰️ Nasłuchiwanie ticków i wykrywanie anomalii...
# [⚠️ WARNING] 2015-02-02T10:20:00 | INFY | Wolumen:  5.38σ → Bądź czujny - Bardzo duży wolumen
# [⚠️ WARNING] 2015-02-02T11:40:00 | RELIANCE | Wolumen:  5.38σ → Bądź czujny - Bardzo duży wolumen
# [⚠️ WARNING] 2015-02-02T11:46:00 | INFY | Wolumen:  5.38σ → Bądź czujny - Bardzo duży wolumen
# [⚠️ WARNING] 2015-02-02T12:22:00 | ICICIBANK | Wolumen:  5.36σ → Bądź czujny - Bardzo duży wolumen
# [⚠️ WARNING] 2015-02-02T13:12:00 | TCS | Wolumen:  5.38σ → Bądź czujny - Bardzo duży wolumen
# [⚠️ WARNING] 2015-02-02T13:30:00 | ICICIBANK | Wolumen:  5.01σ → Bądź czujny - Bardzo duży wolumen
# [⚠️ WARNING] 2015-02-02T13:37:00 | INFY | Wolumen:  5.21σ → Bądź czujny - Bardzo duży wolumen
# [⚠️ WARNING] 2015-02-02T14:15:00 | INFY | Wolumen:  5.38σ → Bądź czujny - Bardzo duży wolumen
# [⚠️ WARNING] 2015-02-02T14:21:00 | RELIANCE | Wolumen:  5.32σ → Bądź czujny - Bardzo duży wolumen
# [⚠️ WARNING] 2015-02-02T14:31:00 | TCS | Wolumen:  5.11σ → Bądź czujny - Bardzo duży wolumen
# [⚠️ WARNING] 2015-02-02T15:22:00 | ICICIBANK | Wolumen:  5.38σ → Bądź czujny - Bardzo duży wolumen
# [⚠️ WARNING] 2015-02-03T11:11:00 | TCS | Wolumen:  5.01σ → Bądź czujny - Bardzo duży wolumen
# [⚠️ WARNING] 2015-02-03T11:39:00 | INFY | Wolumen:  5.37σ → Bądź czujny - Bardzo duży wolumen
# [⚠️ WARNING] 2015-02-03T13:37:00 | RELIANCE | Wolumen:  5.23σ → Bądź czujny - Bardzo duży wolumen
# [⚠️ WARNING] 2015-02-03T14:45:00 | TCS | Wolumen:  5.14σ → Bądź czujny - Bardzo duży wolumen
# [⚠️ WARNING] 2015-02-03T14:54:00 | RELIANCE | Wolumen:  5.15σ → Bądź czujny - Bardzo duży wolumen
# [⚠️ WARNING] 2015-02-04T12:17:00 | RELIANCE | Wolumen:  5.30σ → Bądź czujny - Bardzo duży wolumen
# [⚠️ WARNING] 2015-02-04T12:21:00 | INFY | Wolumen:  5.06σ → Bądź czujny - Bardzo duży wolumen
# [⚠️ WARNING] 2015-02-04T13:18:00 | INFY | Wolumen:  5.38σ → Bądź czujny - Bardzo duży wolumen
# [🔻 SELL] 2015-02-05T09:15:00 | ICICIBANK | Spadek -1.88% + wolumen 2.03σ → Sygnał do sprzedaży
# [⚠️ WARNING] 2015-02-05T09:29:00 | TCS | Wolumen:  5.37σ → Bądź czujny - Bardzo duży wolumen
# [⚠️ WARNING] 2015-02-05T10:41:00 | TCS | Wolumen:  5.33σ → Bądź czujny - Bardzo duży wolumen
# [⚠️ WARNING] 2015-02-05T10:56:00 | INFY | Wolumen:  5.28σ → Bądź czujny - Bardzo duży wolumen
# [⚠️ WARNING] 2015-02-05T11:31:00 | TCS | Wolumen:  5.37σ → Bądź czujny - Bardzo duży wolumen
# [⚠️ WARNING] 2015-02-05T13:03:00 | HDFCBANK | Wolumen:  5.26σ → Bądź czujny - Bardzo duży wolumen
# [⚠️ WARNING] 2015-02-05T13:05:00 | TCS | Wolumen:  5.37σ → Bądź czujny - Bardzo duży wolumen
# [⚠️ WARNING] 2015-02-05T14:02:00 | HDFCBANK | Wolumen:  5.08σ → Bądź czujny - Bardzo duży wolumen
# [⚠️ WARNING] 2015-02-06T10:49:00 | INFY | Wolumen:  5.25σ → Bądź czujny - Bardzo duży wolumen
# [⚠️ WARNING] 2015-02-06T11:35:00 | INFY | Wolumen:  5.17σ → Bądź czujny - Bardzo duży wolumen
# [⚠️ WARNING] 2015-02-06T13:13:00 | RELIANCE | Wolumen:  5.03σ → Bądź czujny - Bardzo duży wolumen
# [⚠️ WARNING] 2015-02
 → Bądź czujny - Bardzo duży wolumen
# [⚠️ WARNING] 2015-06-18T09:15:00 | ICICIBANK | Ruch ceny:  1.35% (ₓ), wolumen:  0.56σ (niski) → Uwaga - możliwa manipulacja, wzrosty bez wolumenu
# [⚠️ WARNING] 2015-06-18T09:57:00 | ICICIBANK | Wolumen:  5.10σ → Bądź czujny - Bardzo duży wolumen
# [⚠️ WARNING] 2015-06-18T12:35:00 | ICICIBANK | Wolumen:  5.32σ → Bądź czujny - Bardzo duży wolumen
# [⚠️ WARNING] 2015-06-18T15:09:00 | ICICIBANK | Wolumen:  5.05σ → Bądź czujny - Bardzo duży wolumen
# [⚠️ WARNING] 2015-06-19T10:22:00 | ICICIBANK | Wolumen:  5.08σ → Bądź czujny - Bardzo duży wolumen
# [⚠️ WARNING] 2015-06-19T12:52:00 | TCS | Wolumen:  5.35σ → Bądź czujny - Bardzo duży wolumen
# [⚠️ WARNING] 2015-06-19T13:58:00 | HDFCBANK | Wolumen:  5.24σ → Bądź czujny - Bardzo duży wolumen
# [⚠️ WARNING] 2015-06-19T14:00:00 | RELIANCE | Wolumen:  5.31σ → Bądź czujny - Bardzo duży wolumen
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 45
#      42 df = pd.read_csv("alerts_log.csv")
#      43 df.iloc[0:0].to_csv("alerts_log.csv", index=False)
# ---> 45 for message in consumer:
#      46     tick = message.value
#      47     timestamp = tick["timestamp"]
#
# File ~\anaconda3\Lib\site-packages\kafka\consumer\group.py:1188, in KafkaConsumer.__next__(self)
#    1186     self._iterator = self._message_generator_v2()
#    1187 try:
# -> 1188     return next(self._iterator)
#    1189 except StopIteration:
#    1190     self._iterator = None
#
# File ~\anaconda3\Lib\site-packages\kafka\consumer\group.py:1160, in KafkaConsumer._message_generator_v2(self)
#    1158 def _message_generator_v2(self):
#    1159     timeout_ms = 1000 * max(0, self._consumer_timeout - time.time())
# -> 1160     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1161     for tp, records in six.iteritems(record_map):
#    1162         # Generators are stateful, and it is possible that the tp / records
#    1163         # here may become stale during iteration -- i.e., we seek to a
#    1164         # different offset, pause consumption, or lose assignment.
#    1165         for record in records:
#    1166             # is_fetchable(tp) should handle assignment changes and offset
#    1167             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1168             # outer function destroying the existing iterator/generator
#    1169             # via self._iterator = None
#
# File ~\anaconda3\Lib\site-packages\kafka\consumer\group.py:684, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     682 timer = Timer(timeout_ms)
#     683 while not self._closed:
# --> 684     records = self._poll_once(timer, max_records, update_offsets=update_offsets)
#     685     if records:
#     686         return records
#
# File ~\anaconda3\Lib\site-packages\kafka\consumer\group.py:731, in KafkaConsumer._poll_once(self, timer, max_records, update_offsets)
#     728     log.debug('poll: do not have all fetch positions...')
#     729     poll_timeout_ms = min(poll_timeout_ms, self.config['retry_backoff_ms'])
# --> 731 self._client.poll(timeout_ms=poll_timeout_ms)
#     732 # after the long poll, we should check whether the group needs to rebalance
#     733 # prior to returning data so that the group can stabilize faster
#     734 if self._coordinator.need_rejoin():
#
# File ~\anaconda3\Lib\site-packages\kafka\client_async.py:685, in KafkaClient.poll(self, timeout_ms, future)
#     678         timeout = min(
#     679             user_timeout_ms,
#     680             metadata_timeout_ms,
#     681             idle_connection_timeout_ms,
#     682             request_timeout_ms)
#     683         timeout = max(0, timeout)  # avoid negative timeouts
# --> 685     self._poll(timeout / 1000)
#     687 # called without the lock to avoid deadlock potential
#     688 # if handlers need to acquire locks
#     689 responses.extend(self._fire_pending_completed_requests())
#
# File ~\anaconda3\Lib\site-packages\kafka\client_async.py:728, in KafkaClient._poll(self, timeout)
#     725 self._register_send_sockets()
#     727 start_select = time.time()
# --> 728 ready = self._selector.select(timeout)
#     729 end_select = time.time()
#     730 if self._sensors:
#
# File ~\anaconda3\Lib\selectors.py:323, in SelectSelector.select(self, timeout)
#     321 ready = []
#     322 try:
# --> 323     r, w, _ = self._select(self._readers, self._writers, [], timeout)
#     324 except InterruptedError:
#     325     return ready
#
# File ~\anaconda3\Lib\selectors.py:314, in SelectSelector._select(self, r, w, _, timeout)
#     313 def _select(self, r, w, _, timeout=None):
# --> 314     r, w, x = select.select(r, w, w, timeout)
#     315     return r, w + x, []
#
# KeyboardInterrupt:

# %%
alerty = pd.read_csv("alerts_log.csv")

# %%
alerty.head(20)
# Out:
#               timestamp     symbol    close   volume  zscore    alert_type  \
# 0   2015-06-12T09:15:00       INFY  1003.28    17882   -1.97  [⚠️ WARNING]
# 1   2015-06-15T09:15:00       INFY   484.60    93524    4.63      [🔻 SELL]
# 2   2015-06-29T09:15:01  ICICIBANK   273.64   202654    4.45      [🔻 SELL]
# 3   2015-06-29T09:15:01   RELIANCE   229.75   319030    4.46      [🔻 SELL]
# 4   2015-07-21T09:15:01       INFY   539.83  1508054    5.38       [🚀 BUY]
# 5   2015-07-27T09:15:01  ICICIBANK   267.00   382104    3.78      [🔻 SELL]
# 6   2015-08-03T09:15:00  ICICIBANK   281.05   717154    1.17  [⚠️ WARNING]
# 7   2015-08-12T09:15:00  ICICIBANK   271.09   180110    0.99  [⚠️ WARNING]
# 8   2015-08-24T09:15:01   RELIANCE   207.20   668024    5.13      [🔻 SELL]
# 9   2015-08-24T09:15:01   HDFCBANK   519.10    33495    1.75  [⚠️ WARNING]
# 10  2015-08-24T09:15:01  ICICIBANK   252.77   538057    5.27      [🔻 SELL]
# 11  2015-08-25T09:15:00  ICICIBANK   250.36   480149    3.19       [🚀 BUY]
# 12  2015-08-25T09:15:00       INFY   558.78   102870   -0.39  [⚠️ WARNING]
# 13  2015-09-09T09:15:00       INFY   548.43   252852    4.86       [🚀 BUY]
# 14  2015-09-29T11:00:00  ICICIBANK   242.32  1310450    5.07       [🚀 BUY]
# 15  2015-10-12T09:16:00       INFY   600.88   981692    4.03       [🚀 BUY]
# 16  2015-10-19T09:15:00   RELIANCE   223.50  1623966    5.36       [🚀 BUY]
# 17  2015-11-09T09:15:00   RELIANCE   218.90   256428    4.85      [🔻 SELL]
# 18  2015-11-09T09:15:00  ICICIBANK   234.73   111096    0.19  [⚠️ WARNING]
# 19  2015-12-10T09:15:00       INFY   520.98    48484   -0.49  [⚠️ WARNING]
#
#                      logged_at
# 0   2025-06-04T18:39:19.915901
# 1   2025-06-04T18:39:21.177235
# 2   2025-06-04T18:39:33.762685
# 3   2025-06-04T18:39:33.764106
# 4   2025-06-04T18:39:53.969255
# 5   2025-06-04T18:39:59.003929
# 6   2025-06-04T18:40:05.303214
# 7   2025-06-04T18:40:14.153679
# 8   2025-06-04T18:40:24.275138
# 9   2025-06-04T18:40:24.277281
# 10  2025-06-04T18:40:24.278008
# 11  2025-06-04T18:40:25.526112
# 12  2025-06-04T18:40:25.528278
# 13  2025-06-04T18:40:39.320097
# 14  2025-06-04T18:40:54.820041
# 15  2025-06-04T18:41:04.622234
# 16  2025-06-04T18:41:10.985203
# 17  2025-06-04T18:41:28.755353
# 18  2025-06-04T18:41:28.756768
# 19  2025-06-04T18:41:54.333679
